# %% [markdown]
# # <span style='color:#DE423F'>*About the Brand*</span>
# ## <span style='color:#243E8D'>*A leading brand in the field of fitness equipment provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.*</span>

# %% [markdown]
# ### <span style='color:#DE423F'>*Bussiness Problem*</span>
# ### <span style='color:#243E8D'>*The market research team of the brand wants to identify the characteristics of the target audience foreach type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across theproduct with respect to customer characteristics.*</span>

# %% [markdown]
# ### <span style='color:#DE423F'>*Solution Approach*</span>
# ### <span style='color:#243E8D'>*Perform descriptive analytics to create a customer profile for each AeroFit treadmill product bydeveloping appropriate tables and charts.*</span>
# ### <span style='color:#243E8D'>*For each AeroFit treadmill product, construct two-way contingency tables and compute allconditional and marginal probabilities along with their insights/impact on the business.*</span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
# !gdown 1Q4tg1JyrYM1v4g_VVofSqmQQiGUh0YBH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q4tg1JyrYM1v4g_VVofSqmQQiGUh0YBH
# To: E:\Notebook\fitness_treadmill.csv
#
#   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# 100%|##########| 7.28k/7.28k [00:00<?, ?B/s]

# %%
df=pd.read_csv(r"E:\Notebook\fitness_treadmill.csv")

# %%
df.head(3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66

# %% [markdown]
# ### <span style='color:#DE423F'>*Data Description*</span>
#
# |<span style='color:#243E8D'>Attribute</span>|<span style='color:#DE423F'>Destription</span>|
# | :--- | ---:|
# |**Product Purchased**|KP281, KP481, or KP781|
# |**Age**|In years|
# |**Gender**|Male/Female|
# |**MaritalStatus**|Single or partnered|
# |**Education**|In years|
# |**Usage**|The average number of times the customer plans to use the treadmill each week|
# |**Income**|Annual income (in $)|
# |**Fitness**|Self-rated fitness on a 1-to-5 scale, where 1 is the poor shape and 5 is the excellent shape.|
# |**Miles**|The average number of miles the customer expects to walk/run each week.|

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# #### **180 Rows and 9 Colimns**

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# #### **No Null Values Present in the Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# #### **Datatypes of the columns**

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ### <span style='color:#DE423F'>Some Observations about Data.</span>
# 1. There are 3 unique products in the data and total of 180 customers.
# 2. KP281 is the most selling product with 80 customers.
# 3. The minimum age of the customers is 18 and maximum age is 50.
# 4. Mean age is 28.78 and 75% of the users have age less than
# 5. Among the users most of them took education for 16 years with maximum of 21 years.
# 6. Most of the users are married, 107 users to be precise.

# %% [markdown]
# ### <span style='color:#DE423F'>Observations about Data on Numerical Columns</span>
# ### <span style='color:#243E8D'>Using Histograms.</span>

# %%
fig=plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
sns.histplot(data=df,
             x=df["Age"],kde=True,color="#1E398E")
plt.subplot(2,3,2)
sns.histplot(data=df,
             x=df["Education"],kde=True,color="#D92725")
plt.subplot(2,3,3)
sns.histplot(data=df,
             x=df["Usage"],kde=True,color="#1E398E")
plt.subplot(2,3,4)
sns.histplot(data=df,
             x=df["Fitness"],kde=True,color="#D92725")
plt.subplot(2,3,5)
sns.histplot(data=df,
             x=df["Income"],kde=True,color="#1E398E")
plt.subplot(2,3,6)
sns.histplot(data=df,
             x=df["Miles"],kde=True,color="#D92725")
plt.suptitle("Observations about Numerical Columns",fontsize=30)
plt.show();

# %% [markdown]
# #### From the plots above we can infer the distribution of the data in terms ofcount of maximun and minimum points of the attributes.

# %% [markdown]
# ### <span style='color:#DE423F'>Observations about Data on Categorical Columns</span>
# ### <span style='color:#243E8D'>Using Countplot.</span>

# %%
fig=plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
sns.countplot(data=df,
             x=df["Product"],color="#1E398E")
plt.subplot(2,3,2)
sns.countplot(data=df,
             x=df["Gender"],color="#D92725")
plt.subplot(2,3,3)
sns.countplot(data=df,
             x=df["MaritalStatus"],color="#1E398E")
plt.suptitle("Observations about Categorical Columns",fontsize=30)
plt.show();

# %% [markdown]
# ### <span style='color:#DE423F'>Outlier Detection Using Box Plot</span>

# %%
fig=plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
sns.boxplot(data=df,
             x=df["Age"],color="#1E398E")
plt.subplot(2,3,2)
sns.boxplot(data=df,
             x=df["Education"],color="#D92725")
plt.subplot(2,3,3)
sns.boxplot(data=df,
             x=df["Usage"],color="#1E398E")
plt.subplot(2,3,4)
sns.boxplot(data=df,
             x=df["Fitness"],color="#D92725")
plt.subplot(2,3,5)
sns.boxplot(data=df,
             x=df["Income"],color="#1E398E")
plt.subplot(2,3,6)
sns.boxplot(data=df,
             x=df["Miles"],color="#D92725")
plt.suptitle("Outlier Detection Using Box Plot",fontsize=30)
plt.show();

# %% [markdown]
# ### <span style='color:#DE423F'>Observations from the box plots</span>
# 1. Columns like "Age", "Education", "Usage", "Fitness" has very lessoutliers
# 2. While columns like "Income" & "Miles" has significant number ofoutliers.

# %% [markdown]
# ### <span style='color:#DE423F'>Checking if features like marital status, age, Gender have any effect on theproduct purchased.</span>

# %%
pd.crosstab(df["Product"],df["Gender"])
# Out:
# Gender   Female  Male
# Product
# KP281        40    40
# KP481        29    31
# KP781         7    33

# %%
pd.crosstab(df["Product"],df["MaritalStatus"])
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281                 48      32
# KP481                 36      24
# KP781                 23      17

# %% [markdown]
# ### <span style='color:#DE423F'>Changing the Numerical Age column to categorical</span>

# %%
age_bracket=[17,25,33,41,50]
label=["Early 20's","Early 30's","Early 40's","Early 50's"]
df["Age_Cat"]=pd.cut(df["Age"],bins=age_bracket,labels=label)

# %%
pd.crosstab(df["Product"],df["Age_Cat"])
# Out:
# Age_Cat  Early 20's  Early 30's  Early 40's  Early 50's
# Product
# KP281            34          27          14           5
# KP481            28          17          13           2
# KP781            17          15           4           4

# %%
fig=plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.countplot(data=df,
              x=df["Product"],
              hue=df["Gender"],palette='tab10')
plt.subplot(1,3,2)
sns.countplot(data=df,
              x=df["Product"],
              hue=df["MaritalStatus"],palette='tab10')
plt.subplot(1,3,3)
sns.countplot(data=df,
              x=df["Product"],
              hue=df["Age_Cat"],palette='tab10')
plt.show();

# %% [markdown]
# ### <span style='color:#DE423F'>From the above data and the plots we can infer that</span>
#
#     Product Vs Gender
#     1. For KP281 the base model the count of male and female users are same.
#     2. For KP481 the mediocre male users are slightly more than the female users.
#     3. For the premium model KP781 count of male users is significantly high.
#
#
#     Product Vs Marital Status
#     1. For all the 3 models the count of married users is higher than that of unmarried users.
#
#
#     Product Vs Age
#     For this I have categorised the Age column in 4 Categories i.e.
#     a. "Early 20's" which is 18-25
#     b. "Early 30's" which is 26-33
#     c. "Early 40's" which is 34-41
#     d. "Early 50's" which is 42-50.
#
#     1.For all the 3 models the count of users in their early 20's is higher than the other 3
#     2. Maximum users buying KP781 which is the premium model are in the age bracket 18-30

# %% [markdown]
# ### <span style='color:#DE423F'>Checking if features like Age, Education, Usage, Fitness, Income & Miles haveany effect on the product purchased</span>

# %%
fig=plt.figure(figsize=(18,12))
plt.subplot(2,3,1)
ax=sns.boxplot(data=df,
               y=df["Age"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Age",fontsize=10)
plt.subplot(2,3,2)
ax=sns.boxplot(data=df,
               y=df["Education"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Education",fontsize=10)
plt.subplot(2,3,3)
ax=sns.boxplot(data=df,
               y=df["Usage"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Usage",fontsize=10)
plt.subplot(2,3,4)
ax=sns.boxplot(data=df,
               y=df["Fitness"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Fitness",fontsize=10)
plt.subplot(2,3,5)
ax=sns.boxplot(data=df,
               y=df["Income"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Income",fontsize=10)
plt.subplot(2,3,6)
ax=sns.boxplot(data=df,
               y=df["Miles"],
               x=df["Product"],palette='tab10')
plt.title("Product Vs Miles",fontsize=10)
plt.show();

# %% [markdown]
#     Product Vs Age
#     1. The 50th percentile age or the median age is same for the KP281 and KP481.
#     2. User buying the permium model KP781 lies in between 25-30 years only.
#     3. The age of user buying KP781 contains many ouliers.
#
#     Product Vs Education
#     1. User's whose education is more than 16 is more likely to buy KP781.
#     2. User's buying KP281 or KP481 have the same education which is in between 14 to 16.
#
#     Product Vs Usage
#     1. Users planning to use the treadmil between 4-5 hours is more likely to buy KP781.
#     2. Users planning to use the treadmil between 3-4 hours is more likely to buy KP281.
#
#     Product Vs Fitness
#     1. Users who rate themselves above 4 is more likely to buy KP781.
#
#     Product Vs Income
#     1. For KP281- The income lies in the range 40K-50K
#     2. For KP481- The income lies in the range 45K-55K
#     3. For KP781- The income is above 60K
#     From this we can say that higer the income the chance of buying KP781 is more.
#
#     Product Vs Miles
#     1. Users planning to use the treadmil for more than 120 miles is more likely to buy KP781

# %% [markdown]
# ### <span style='color:#DE423F'>Finding Corelations among Columns</span>

# %%
df.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
fig=plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.show();

# %% [markdown]
# ### <span style='color:#DE423F'>From the Heatmap we can infer that</span>
#     1.Age & Income are slightly Co-related.
#     2.Education & Income is also Co-related.
#     3.Usage & Fitness and Usage & Miles are Co-related.
#     4.Usage & Income is slightly Co-related.
#     5.Fitness is corelated with Usage, Income, & Miles.
#     6.Income is more or less Co-relatedted with all columns.
#     7.Miles is Co-related with Usage, Fitness and slighty corelated to Income
#     8.All the other columns are negatively corelated.

# %% [markdown]
# ### <span style='color:#DE423F'>Computing Marginal Probabilities</span>

# %%
round(df["Product"].value_counts(normalize=True),2)
# Out:
# KP281    0.44
# KP481    0.33
# KP781    0.22
# Name: Product, dtype: float64

# %% [markdown]
# **So, the probability of a user purchasing**
# 1. KP281 is 44%
# 2. KP481 is 33%
# 3. KP781 is 22%

# %%
round(df["Gender"].value_counts(normalize=True),2)
# Out:
# Male      0.58
# Female    0.42
# Name: Gender, dtype: float64

# %% [markdown]
# **So, the probability of a user being**
# 1. Male is 58%
# 2. Female is 42%

# %%
round(df["MaritalStatus"].value_counts(normalize=True),2)
# Out:
# Partnered    0.59
# Single       0.41
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# **So, the probability of a user being**
# 1. Partnered is 59%
# 2. Single is 41%

# %% [markdown]
# ### <span style='color:#DE423F'>Computing Conditional Probabilities</span>
#
# #### <span style='color:#243E8D'>Purchasing Treadmill given Gender</span>

# %%
round(pd.crosstab(df["Product"],df["Gender"],normalize="columns"),2)
# Out:
# Gender   Female  Male
# Product
# KP281      0.53  0.38
# KP481      0.38  0.30
# KP781      0.09  0.32

# %% [markdown]
#     The probability of purchasing a treadmill KP281 given user is male
#     P(KP281|Male) is 38%
#     The probability of purchasing a treadmill KP481 given user is male
#     P(KP481|Male) is 30%
#     The probability of purchasing a treadmill KP781 given user is male
#     P(KP781|Male) is 32%
#
#     The probability of purchasing a treadmill KP281 given user is Female
#     P(KP281|Female) is 53%
#     The probability of purchasing a treadmill KP481 given user is Female
#     P(KP481|Female) is 38%
#     The probability of purchasing a treadmill KP781 given user is Female
#     P(KP781|Female) is 9%

# %% [markdown]
# #### <span style='color:#243E8D'>Purchasing Treadmill given Marital Status</span>

# %%
round(pd.crosstab(df["Product"],df["MaritalStatus"],normalize="columns"),2)
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281               0.45    0.44
# KP481               0.34    0.33
# KP781               0.21    0.23

# %% [markdown]
#     The probability of purchasing a treadmill KP281 given user is Partnered/Married
#     P(KP281|Partnered) is 45%
#     The probability of purchasing a treadmill KP481 given user is Partnered/Married
#     P(KP481|Partnered) is 34%
#     The probability of purchasing a treadmill KP781 given user is Partnered/Married
#     P(KP781|Partnered) is 21%
#
#     The probability of purchasing a treadmill KP281 given user is Single/Unmarried
#     P(KP281|Single) is 44%
#     The probability of purchasing a treadmill KP481 given user is Single/Unmarried
#     P(KP481|Single) is 33%
#     The probability of purchasing a treadmill KP781 given user is Single/Unmarried
#     P(KP781|Single) is 23%
